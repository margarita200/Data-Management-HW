# %% [markdown]
# # Предобработка данных для загрузки в ХД

# %% [markdown]
# Наши данные достаточно сложные и "грязные", поэтому было принято решение предобработать их с помощью Python. Через данную процедуру можно "пропустить" любой файл. Формат входного файла легко меняется.

# %%
import pandas as pd
import numpy as np
import operator
from tqdm import tqdm

# %% [markdown]
# # Загрузка файла

# %%
data = pd.read_excel('kofe-2.xlsx')
data.drop('id', axis=1, inplace=True)
data.shape
# Out:
# (1354, 52)

# %%
data.describe()
# Out:
#        view_certificate_2  Cupping Protocol and Descriptors  \
# count                 0.0                               0.0
# mean                  NaN                               NaN
# std                   NaN                               NaN
# min                   NaN                               NaN
# 25%                   NaN                               NaN
# 50%                   NaN                               NaN
# 75%                   NaN                               NaN
# max                   NaN                               NaN
#
#        View Green Analysis Details  Request a Sample  Number of Bags  \
# count                          0.0               0.0     1340.000000
# mean                           NaN               NaN      154.067910
# std                            NaN               NaN      130.006861
# min                            NaN               NaN        0.000000
# 25%                            NaN               NaN       14.000000
# 50%                            NaN               NaN      172.500000
# 75%                            NaN               NaN      275.000000
# max                            NaN               NaN     1062.000000
#
#              Aroma       Flavor   Aftertaste      Acidity         Body  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean      7.565822     7.519447     7.400321     7.535456     7.519925
# std       0.380020     0.400681     0.405779     0.380310     0.361393
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       7.420000     7.330000     7.250000     7.330000     7.330000
# 50%       7.580000     7.580000     7.420000     7.580000     7.500000
# 75%       7.750000     7.750000     7.580000     7.750000     7.670000
# max       8.750000     8.830000     8.670000     8.750000     8.580000
#
#            Balance   Uniformity    Clean Cup    Sweetness  Cupper Points  \
# count  1338.000000  1338.000000  1338.000000  1338.000000    1338.000000
# mean      7.516114     9.827780     9.828012     9.846809       7.502571
# std       0.417102     0.616347     0.810022     0.684383       0.475218
# min       0.000000     0.000000     0.000000     0.000000       0.000000
# 25%       7.330000    10.000000    10.000000    10.000000       7.250000
# 50%       7.500000    10.000000    10.000000    10.000000       7.500000
# 75%       7.750000    10.000000    10.000000    10.000000       7.750000
# max       8.750000    10.000000    10.000000    10.000000      10.000000
#
#        NA.2     Moisture      Quakers  NA.3  Unnamed: 51
# count   0.0  1338.000000  1337.000000   0.0          0.0
# mean    NaN     0.088281     0.173523   NaN          NaN
# std     NaN     0.048359     0.832419   NaN          NaN
# min     NaN     0.000000     0.000000   NaN          NaN
# 25%     NaN     0.090000     0.000000   NaN          NaN
# 50%     NaN     0.110000     0.000000   NaN          NaN
# 75%     NaN     0.120000     0.000000   NaN          NaN
# max     NaN     0.280000    11.000000   NaN          NaN

# %% [markdown]
# # Удаление столбцов

# %%
def search_nulles(data):
    nulles = data.isnull().sum().sort_values(ascending=False)
    percent = (data.isnull().sum()/data.isnull().count()).sort_values(ascending=False)
    missing_data = pd.concat([nulles, percent], axis=1, keys=['Nulles', 'Percent'])
    return missing_data

search_nulles(data).head(30)
# Out:
#                                   Nulles   Percent
# view_certificate_2                  1354  1.000000
# Cupping Protocol and Descriptors    1354  1.000000
# View Green Analysis Details         1354  1.000000
# NA.3                                1354  1.000000
# Request a Sample                    1354  1.000000
# Unnamed: 51                         1354  1.000000
# NA.2                                1354  1.000000
# view_certificate_1                  1352  0.998523
# Notes                               1349  0.996307
# Lot Number                          1078  0.796160
# Farm Name                            373  0.275480
# Mill                                 329  0.242984
# Producer                             246  0.181684
# Variety                              243  0.179468
# Altitude                             236  0.174298
# Color                                235  0.173560
# Company                              224  0.165436
# Processing Method                    187  0.138109
# ICO Number                           171  0.126292
# Region                                72  0.053176
# Harvest Year                          62  0.045790
# Owner.1                               23  0.016987
# Owner                                 21  0.015510
# NA                                    18  0.013294
# Certification Contact                 17  0.012555
# Quakers                               17  0.012555
# Total Cup Points                      16  0.011817
# Moisture                              16  0.011817
# NA.1                                  16  0.011817
# Category One Defects                  16  0.011817

# %% [markdown]
# Смотрим, сколько в каждом столбце нулевых значений. Так как такие столбцы не несут особой полезности, то в дальнейшем мы не будем добавлять их в таблицу export_table ( это настраивается далее в Talend )
#
# Так как некоторые столбцы полностью заполнены нулевыми значениями, то их можно удалить
# Более того, можно удалить столбцы с более 50% пропусков

# %%
# data.drop("Cupping Protocol and Descriptors", axis=1, inplace=True)
# data.drop("View Green Analysis Details", axis=1, inplace=True)
# data.drop("NA.3", axis=1, inplace=True)
# data.drop("Request a Sample", axis=1, inplace=True)
# data.drop("Unnamed: 51", axis=1, inplace=True)
# data.drop("NA.2", axis=1, inplace=True)
# data.drop("view_certificate_2", axis=1, inplace=True)
# data.drop("view_certificate_1", axis=1, inplace=True)
# data.drop("Notes", axis=1, inplace=True)
# data.drop("Lot Number", axis=1, inplace=True)

# %% [markdown]
# Заметим, что в самом конце таблицы с нулями есть атрибуты с одинаковым количеством нулей. Посмотрим на эти данные. Есть целые строчки с нулевыми значениям. Так как они не несут нам пользы - удалим их

# %%
data[data['Farm Name'].isnull() == False][['Owner', 'Owner.1', 'Farm Name', 'Mill', 'Company', 'Producer']].head(50)
# Out:
#                                  Owner                             Owner.1  \
# 0                            metad plc                           metad plc
# 1                            metad plc                           metad plc
# 2             Grounds for Health Admin            Grounds for Health Admin
# 3                  Yidnekachew Dabessa                 Yidnekachew Dabessa
# 4                            metad plc                           metad plc
# 7          Ethiopia Commodity Exchange         Ethiopia Commodity Exchange
# 8          Ethiopia Commodity Exchange         Ethiopia Commodity Exchange
# 9               Diamond Enterprise Plc              Diamond Enterprise Plc
# 10                       Mohammed Lalo                       Mohammed Lalo
# 11  CQI Q Coffee Sample Representative  CQI Q Coffee Sample Representative
# 12  CQI Q Coffee Sample Representative  CQI Q Coffee Sample Representative
# 13            Grounds for Health Admin            Grounds for Health Admin
# 14         Ethiopia Commodity Exchange         Ethiopia Commodity Exchange
# 15  CQI Q Coffee Sample Representative  CQI Q Coffee Sample Representative
# 16            Grounds for Health Admin            Grounds for Health Admin
# 18              Yunnan Coffee Exchange              Yunnan Coffee Exchange
# 19                       EssenceCoffee                       EssenceCoffee
# 20  CQI Q Coffee Sample Representative  CQI Q Coffee Sample Representative
# 21              The Coffee Source Inc.              The Coffee Source Inc.
# 22               ROBERTO LICONA FRANCO               ROBERTO LICONA FRANCO
# 23  CQI Q Coffee Sample Representative  CQI Q Coffee Sample Representative
# 25                            NUCOFFEE                            NUCOFFEE
# 27               Kabum Trading company               Kabum Trading company
# 28                     Bismarck Castro                     Bismarck Castro
# 29              Lin, Che-Hao Krude 林哲豪              Lin, Che-Hao Krude 林哲豪
# 32                            NUCOFFEE                            NUCOFFEE
# 33                    Francisco A Mena                    Francisco A Mena
# 34                      Hider Abamecha                      Hider Abamecha
# 35                         Daniel Magu                         Daniel Magu
# 37    Kona Pacific Farmers Cooperative    Kona Pacific Farmers Cooperative
# 38         Ethiopia Commodity Exchange         Ethiopia Commodity Exchange
# 39  CQI Q Coffee Sample Representative  CQI Q Coffee Sample Representative
# 40                  ITDP International                  ITDP International
# 41            Jacques Pereira Carneiro            Jacques Pereira Carneiro
# 42            Jacques Pereira Carneiro            Jacques Pereira Carneiro
# 43              Lin, Che-Hao Krude 林哲豪              Lin, Che-Hao Krude 林哲豪
# 44                       Jungle Estate                       Jungle Estate
# 45                            NUCOFFEE                            NUCOFFEE
# 46           Great Lakes Coffee Uganda           Great Lakes Coffee Uganda
# 47                           LUSSO LAB                           LUSSO LAB
# 48                           LUSSO LAB                           LUSSO LAB
# 50         Ethiopia Commodity Exchange         Ethiopia Commodity Exchange
# 51            Grounds for Health Admin            Grounds for Health Admin
# 52           Juan Luis Alvarado Romero           Juan Luis Alvarado Romero
# 53                  Kawacom Uganda LTD                  Kawacom Uganda LTD
# 55                   Gonzalo Hernandez                   Gonzalo Hernandez
# 57           Juan Luis Alvarado Romero           Juan Luis Alvarado Romero
# 58           Juan Luis Alvarado Romero           Juan Luis Alvarado Romero
# 59       SEID DAMTEW COFFEE PLANATAION       SEID DAMTEW COFFEE PLANATAION
# 61           Colbran Coffeelands, Ltd.           Colbran Coffeelands, Ltd.
#
#                                    Farm Name  \
# 0                                  METAD PLC
# 1                                  METAD PLC
# 2   San Marcos Barrancas "San Cristobal Cuch
# 3      Yidnekachew Dabessa Coffee Plantation
# 4                                  METAD PLC
# 7                                      Aolme
# 8                                      Aolme
# 9                          Tulla Coffee Farm
# 10                   Fahem Coffee Plantation
# 11                                   El filo
# 12                                Los Cedros
# 13                             Arianna Farms
# 14                                     Aolme
# 15                                 El Águila
# 16                               Toarco Jaya
# 18                               Echo Coffee
# 19                                Drima Zede
# 20                                  El Rodeo
# 21                                   SEVERAL
# 22                              LA HERRADURA
# 23                                  La curva
# 25                           Fazenda Kaquend
# 27                Chebonet (23) women coffee
# 28                              Los Hicaques
# 29                  Tsoustructive Garden 鄒築園
# 32                           Fazenda Recreio
# 33                    Exclusive Coffees S.A.
# 34         Haider Abamecha Coffee Plantation
# 35                                   Kangunu
# 37                Kona Pacific Farmers Co-Op
# 38  Phone number | 0911-51-08-01, Email | at
# 39                              La Primavera
# 40                                 Co-op #12
# 41                     Pereira Estate Coffee
# 42                     Pereira Estate Coffee
# 43             Sunshine Valley Estate 向陽高山咖啡
# 44                             JUNGLE ESTATE
# 45                           Fazenda Kaquend
# 46                                   Kaasayi
# 47                           Ecobio Colombia
# 48                                  KIANJAVI
# 50           Contact | sidacoop@ethionet.net
# 51                    Hula Daddy Kona Coffee
# 52                     LA ESPERANZA Y ANEXOS
# 53               Sipi organic coffee project
# 55                         La Berlina Estate
# 57                                VALPARAISO
# 58                            FINCA EL LIMON
# 59  seid damtew coffee export and plantation
# 61                    Tairora Cherry – Bonta
#
#                                                  Mill  \
# 0                                           METAD PLC
# 1                                           METAD PLC
# 2                                                 NaN
# 3                                             Wolensu
# 4                                           METAD PLC
# 7                                             C.P.W.E
# 8                                             C.P.W.E
# 9                                   Tulla Coffee Farm
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                            C.P.W.E
# 15                                                NaN
# 16                                                NaN
# 18                                   Echo Coffee Mill
# 19                                         Drima Zede
# 20                                                NaN
# 21                           CAFE DE ALTURA SAN RAMON
# 22                                       LA HERRADURA
# 23                                                NaN
# 25                                                NaN
# 27                              Kabum trading company
# 28                                CIGRAH S.A. DE C.V.
# 29                           Tsoustructive Garden 鄒築園
# 32                                                NaN
# 33                             Exclusive Coffees S.A,
# 34      Faysal Abamecha Processing Plant at yebu Town
# 35                         central kenya coffee mills
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                           Cocarive
# 42                                           Cocarive
# 43                      Sunshine Valley Estate 向陽高山咖啡
# 44                                   NKG COFFEE MILLS
# 45                                                NaN
# 46                                        Great Lakes
# 47                                                NaN
# 48                                                NaN
# 50           Coffee Processing and Warehouse Enterpri
# 51                                                NaN
# 52                                   BENEFICIO IXCHEL
# 53                                    Kawacom (U) Ltd
# 55                           Beneficio Casa Ruiz S.A.
# 57                               BENEFICIO VALPARAISO
# 58  BENEFICIO SERBEN KM 21.5 CARRETERA A VILLA CAN...
# 59           seid damtew coffee export and plantation
# 61                                            Baroida
#
#                                   Company  \
# 0       METAD Agricultural Developmet plc
# 1       METAD Agricultural Developmet plc
# 2                                     NaN
# 3   Yidnekachew Debessa Coffee Plantation
# 4       METAD Agricultural Developmet plc
# 7                                     NaN
# 8                                     NaN
# 9                  DIAMOND ENTERPRISE PLC
# 10                Fahem Coffee Plantation
# 11               Coffee Quality Institute
# 12               Coffee Quality Institute
# 13                                    NaN
# 14                                    NaN
# 15               Coffee Quality Institute
# 16                                    NaN
# 18                 Yunnan Coffee Exchange
# 19                         Essence Coffee
# 20               Coffee Quality Institute
# 21                 The Coffee Source Inc.
# 22                                    NaN
# 23               Coffee Quality Institute
# 25                               NUCOFFEE
# 27                  Kabum Trading company
# 28                      CIGRAH S.A DE C.V
# 29               Taiwan Coffee Laboratory
# 32                               NUCOFFEE
# 33                 Exclusive Coffees S.A.
# 34          Haider Abamecha Coffee Export
# 35                           C dorman Ltd
# 37                                    NaN
# 38                                    NaN
# 39               Coffee Quality Institute
# 40                             Lanna Cafe
# 41                                    NaN
# 42                                    NaN
# 43               Taiwan Coffee Laboratory
# 44                       Keremara Limited
# 45                               NUCOFFEE
# 46                                   UCDA
# 47                       LUSSO COFFEE LAB
# 48                       LUSSO COFFEE LAB
# 50                                    NaN
# 51                                    NaN
# 52                   UNEX GUATEMALA, S.A.
# 53                     Kawacom uganda LTD
# 55                      CE Specialty S.A.
# 57                               SERTRASA
# 58                           UNICAFE, S.A
# 59           Seid Damtew Coffee Planation
# 61                                    CQI
#
#                                      Producer
# 0                                   METAD PLC
# 1                                   METAD PLC
# 2                                         NaN
# 3       Yidnekachew Dabessa Coffee Plantation
# 4                                   METAD PLC
# 7   Bazen Agricultural & Industrial Dev't Plc
# 8   Bazen Agricultural & Industrial Dev't Plc
# 9                      Diamond Enterprise Plc
# 10                    Fahem Coffee Plantation
# 11               Alfredo De Jesús López Pérez
# 12                      Jorge Walter Restrepo
# 13               Robert, Sharon, Arianna Wood
# 14  Bazen Agricultural & Industrial Dev't Plc
# 15                        María Leticia Diosa
# 16                           P.T. Toarco Jaya
# 18                                Echo Coffee
# 19                                    LevelUp
# 20                       Nicolás Rueda Urrego
# 21                                    SEVERAL
# 22                      ROBERTO LICONA FRANCO
# 23                       Silvia Elena Higuita
# 25                            Ralph Junqueira
# 27                      Kabum trading company
# 28                            Reinerio Zepeda
# 29                         FANG,ZHENG-LUN 方政倫
# 32            Homero Texeira de Macedo Junior
# 33                     Exclusive Coffees S.A.
# 34                    Haider Abamecha Abadiko
# 35                                    Kangunu
# 37                 Kona Pacific Farmers Co-Op
# 38          Contact name | ATO Teshome Belamo
# 39                     Hugo Sepúlveda Montoya
# 40                                       ITDP
# 41                Maria Rogeria Costa Pereira
# 42                Maria Rogeria Costa Pereira
# 43                          LIN YEN CHIEN 林言謙
# 44                              JUNGLE ESTATE
# 45                            Ralph Junqueira
# 46                        Kaasay Farmer Group
# 47                                        NaN
# 48                                        NaN
# 50          Sidama Coffee Farmers Coop. Union
# 51                     Hula Daddy Kona Coffee
# 52                  MARGARITA AVILA DE NUYENS
# 53                             Kawacom (U)Ltd
# 55                                Plinio Ruiz
# 57                                   SERTRASA
# 58          WILLIAM ESTUARDO MARTINEZ PACHECO
# 59   seid damtew coffee export and plantation
# 61                  Colbran CoffeeLands, Ltd.

# %%
data[data['Owner'] != data['Owner.1']][['Owner', 'Owner.1']]
# Out:
#                          Owner    Owner.1
# 219                 CECA, S.A.  CECA,S.A.
# 364                        NaN        NaN
# 459                        NaN        NaN
# 602                        NaN        NaN
# 848                        NaN        NaN
# 882                        NaN        NaN
# 918                        NaN        NaN
# 921                        NaN        NaN
# 922                        NaN        NaN
# 964              Klem Organics        NaN
# 965                        NaN        NaN
# 966                        NaN        NaN
# 967                        NaN        NaN
# 981                        NaN        NaN
# 1050                       NaN        NaN
# 1089  CQI Taiwan ICP CQI台灣合作夥伴        NaN
# 1090                       NaN        NaN
# 1091                       NaN        NaN
# 1092                       NaN        NaN
# 1093                       NaN        NaN
# 1094                       NaN        NaN
# 1095                       NaN        NaN
# 1242                       NaN        NaN
# 1243                       NaN        NaN

# %%
# data.drop("Owner.1", axis=1, inplace=True)

# %% [markdown]
# Удаляем Owner.1 тк этот столбец фактически дублирует Owner

# %%
data[data['NA'] != data['NA.1']][['NA', 'NA.1']]
# data.drop("NA", axis=1, inplace=True)
# Out:
#        NA    NA.1
# 352   NaN  Sample
# 379   NaN  Sample
# 918   NaN     NaN
# 920   NaN     NaN
# 922   NaN     NaN
# 964   NaN     NaN
# 965   NaN     NaN
# 966   NaN     NaN
# 967   NaN     NaN
# 1089  NaN     NaN
# 1090  NaN     NaN
# 1091  NaN     NaN
# 1092  NaN     NaN
# 1093  NaN     NaN
# 1094  NaN     NaN
# 1095  NaN     NaN
# 1242  NaN     NaN
# 1243  NaN     NaN

# %% [markdown]
# Удаляем NA тк этот столбец фактически дублирует NA.1

# %% [markdown]
# # Удаление строк

# %%
nulles = {}

def isNaN(num):
    return num != num

def NaN_in_row(data):
    i = 0
    while i < len(data):
        line = data.iloc[i]
        for item in line:
            if isNaN(item):
                if i in nulles.keys():
                    nulles[i] += 1
                else:
                    nulles[i] = 1
        i += 1
    return dict(sorted(nulles.items(), key=operator.itemgetter(1), reverse=True))

print('Посмотрим, сколько есть записей с нулевыми ячейками')
nulles = NaN_in_row(data)
list(nulles.items())[:20]
# Out:
# Посмотрим, сколько есть записей с нулевыми ячейками
# [(967, 52),
#  (1091, 52),
#  (1093, 52),
#  (1094, 52),
#  (1095, 52),
#  (1242, 52),
#  (1243, 52),
#  (918, 51),
#  (922, 51),
#  (965, 51),
#  (1090, 51),
#  (966, 50),
#  (1092, 50),
#  (1089, 39),
#  (964, 36),
#  (920, 35),
#  (921, 28),
#  (1209, 21),
#  (334, 20),
#  (373, 20)]

# %%
d = dict((k, v) for k, v in nulles.items() if v >= 35)
drop = list(d)

data.drop(data.index[drop], inplace=True)

data.reset_index()
print('Удалим строки, в которых больше 34 нулевых значений \nтк вряд ли они несут пользу для нашего анализа, ведь всего 52 столбца')
# Out:
# Удалим строки, в которых больше 34 нулевых значений
# тк вряд ли они несут пользу для нашего анализа, ведь всего 52 столбца

# %% [markdown]
# # Заполнение нулей

# %%
data[data['Owner'].isnull()][['Owner', 'Farm Name', 'Mill', 'Company', 'Producer']].head(21)
# Out:
#      Owner                   Farm Name         Mill        Company  \
# 364    NaN                Los Hicaques   CIGRAH SPS         CIGRAH
# 459    NaN                Los Hicaques   CIGRAH SPS         CIGRAH
# 602    NaN  Supply Chain ECOM CCA S.A.  South Huila  ECOM CCA S.A.
# 848    NaN  Gran Manzana y el Aguacate   CIGRAH SPS         CIGRAH
# 882    NaN  Gran Manzana y el Aguacate   CIGRAH SPS         CIGRAH
# 921    NaN                         NaN          NaN            NaN
# 981    NaN                Los Hicaques       CIGRAH         CIGRAH
# 1050   NaN                Los Hicaques       CIGRAH         CIGRAH
#
#                         Producer
# 364              Reynerio Zepeda
# 459              Reynerio Zepeda
# 602   Supply Chain ECOM CCA S.A.
# 848      Tomás Sosa, Juan Damaso
# 882      Tomás Sosa, Juan Damaso
# 921                          NaN
# 981              Reinerio Zepeda
# 1050             Reinerio Zepeda

# %%
data[data['Company'] == 'CIGRAH'][['Owner', 'Farm Name', 'Mill', 'Company', 'Producer', 'Region', 'Altitude', 'ICO Number', 'In-Country Partner']].head(21)
# Out:
#            Owner                   Farm Name               Mill Company  \
# 364          NaN                Los Hicaques         CIGRAH SPS  CIGRAH
# 459          NaN                Los Hicaques         CIGRAH SPS  CIGRAH
# 655   Elsy Reyes               Las Cuchillas  CIGRAH S.A DE C.V  CIGRAH
# 848          NaN  Gran Manzana y el Aguacate         CIGRAH SPS  CIGRAH
# 882          NaN  Gran Manzana y el Aguacate         CIGRAH SPS  CIGRAH
# 912   Elsy Reyes               LAS CUCHILLAS             CIGRAH  CIGRAH
# 981          NaN                Los Hicaques             CIGRAH  CIGRAH
# 1050         NaN                Los Hicaques             CIGRAH  CIGRAH
#
#                      Producer          Region   Altitude  ICO Number  \
# 364           Reynerio Zepeda       Comayagua       1350  13-111-240
# 459           Reynerio Zepeda       Comayagua       1350  13-111-193
# 655           Nahun Maldonado       Comayagua       1400  13-111-097
# 848   Tomás Sosa, Juan Damaso       Comayagua       1350  13-111-311
# 882   Tomás Sosa, Juan Damaso       Comayagua       1400  13-111-192
# 912           NAHUN MALDONADO       COMAYAGUA       1400  13-111-083
# 981           Reinerio Zepeda  Central Region  1450 mals  13-111-037
# 1050          Reinerio Zepeda  Central Region  1450 mals  13-111-035
#
#                 In-Country Partner
# 364   Instituto Hondureño del Café
# 459   Instituto Hondureño del Café
# 655   Instituto Hondureño del Café
# 848   Instituto Hondureño del Café
# 882   Instituto Hondureño del Café
# 912   Instituto Hondureño del Café
# 981   Instituto Hondureño del Café
# 1050  Instituto Hondureño del Café

# %% [markdown]
# Так как мы хотим использовать Owner как первичный составной ключ,
# то нельзя допустить в нём нулевые значения. Заполняем их уникальным значением владельца в этой компании

# %%
owner = data[data['Company'] == 'CIGRAH']['Owner'].unique()[1]
nan_index = data[data['Owner'].isnull()].index
data.loc[nan_index, 'Owner'] = pd.Series(owner, index=nan_index)

# %%
nan_index = data[data['Quakers'].isnull()].index
data.loc[nan_index, 'Quakers'] = pd.Series(0, index=nan_index)

# %% [markdown]
# # Декомпозиция данных

# %%
def split_weight(data):
    for i in tqdm(range(len(data))):
        item = data.iloc[i, 18]
        if isinstance(item, int):
            weigth = item
        elif not isNaN(item):
            words = item.split(' ')
            weigth = int(words[0])
            if len(words) > 1:
                metric = words[1]
                if metric.lower().strip() == 'lbs':
                    weigth = weigth * 0.453592
        data.iloc[i, 18] = round(weigth, 3)
    return data

# %%
data.iloc[1, 17:25]
# Out:
# Number of Bags                                       300
# Bag Weight                                         60 kg
# In-Country Partner    METAD Agricultural Development plc
# Harvest Year                                        2014
# Grading Date                             April 4th, 2015
# Owner.1                                        metad plc
# Variety                                            Other
# Status                                         Completed
# Name: 1, dtype: object

# %%
def float_to_int(data):
    for i in tqdm(range(len(data))):
        item = data.iloc[i, 17]
        number = int(item)
        data.iloc[i, 17] = number
    return data

# %%
data = split_weight(data)
data['Bag Weight']
# Out:
# 100%|██████████| 1338/1338 [00:00<00:00, 2086.34it/s]
# 0          60
# 1          60
# 2           1
# 3          60
# 4          60
#         ...
# 1349        2
# 1350        2
# 1351        1
# 1352    2.268
# 1353    2.268
# Name: Bag Weight, Length: 1338, dtype: object

# %%
def split_defects(data, number='one'):
    for i in tqdm(range(len(data))):
        if number == 'one':
            k = 41
        elif number == 'two':
            k = 44
        item = data.iloc[i, k]
        if isNaN(item) is False:
            words = item.split(' ')
            defects = int(words[0])
        data.iloc[i, k] = defects
            
    return data

# %%
data = split_defects(data)
data = split_defects(data, 'two')
# Out:
# 100%|██████████| 1338/1338 [00:00<00:00, 1872.51it/s]
# 100%|██████████| 1338/1338 [00:00<00:00, 1977.44it/s]

# %%
data['Expiration']
# Out:
# 0           April 3rd, 2016
# 1           April 3rd, 2016
# 2            May 31st, 2011
# 3          March 25th, 2016
# 4           April 3rd, 2016
#                ...
# 1349     January 18th, 2017
# 1350     January 18th, 2017
# 1351    December 23rd, 2015
# 1352      August 25th, 2015
# 1353      August 25th, 2015
# Name: Expiration, Length: 1338, dtype: object

# %%
import datetime

months = {'January': 1, 'February': 2, 'March': 3, 'April': 4, 
          'May': 5, 'June': 6, 'July': 7, 'August': 8,
          'September': 9, 'October': 10, 'November': 11, 'December': 12}

# %%
def string_to_date(data, date='export'):
    if date == 'export':
        k = 46
    elif date == 'grading':
        k = 21
    
    for i in tqdm(range(len(data))):
        item = data.iloc[i, k]
        if not isNaN(item):
            words = item.split(' ')
            if len(words) > 2:
                month = words[0]
                day = words[1][:-3]
                year = words[2]
                data.iloc[i, k] = datetime.date(year=int(year), month=months[month], day=int(day))
    return data

data = string_to_date(data)
data = string_to_date(data, date='grading')
data['Grading Date']
# Out:
# 100%|██████████| 1338/1338 [00:00<00:00, 1837.76it/s]
# 100%|██████████| 1338/1338 [00:00<00:00, 1699.30it/s]
# 0       2015-04-04
# 1       2015-04-04
# 2       2010-05-31
# 3       2015-03-26
# 4       2015-04-04
#            ...
# 1349    2016-01-19
# 1350    2016-01-19
# 1351    2014-12-23
# 1352    2014-08-25
# 1353    2014-08-25
# Name: Grading Date, Length: 1338, dtype: object

# %%
import random
import datetime

def add_transact_data(data):
    
    transactions = []
    j = 0
    for i in tqdm(range(len(data))):
        export = data.iloc[i, 46]
        grade = data.iloc[i, 21]
        start_date = grade
        end_date = export
        if not isNaN(start_date):

            time_between_dates = end_date - start_date
            days_between_dates = time_between_dates.days

            random_number_of_days = random.randrange(days_between_dates)
            random_date = start_date + datetime.timedelta(days=random_number_of_days)
            transactions.append(random_date)
        else:
            transactions.append(grade)
        j += 1
    data['Export Date'] = transactions
            
    return data

data = add_transact_data(data)
# Out:
# 100%|██████████| 1338/1338 [00:00<00:00, 42688.98it/s]

# %%
data['Export Date']
# Out:
# 0       2015-06-13
# 1       2015-11-18
# 2       2010-07-24
# 3       2015-06-02
# 4       2016-01-22
#            ...
# 1349    2016-08-07
# 1350    2016-04-10
# 1351    2015-02-10
# 1352    2015-07-25
# 1353    2014-11-05
# Name: Export Date, Length: 1338, dtype: object

# %%
data.iloc[2, 21]
# Out:
# datetime.date(2010, 5, 31)

# %%
data['Number of Bags']
# Out:
# 0       300.0
# 1       300.0
# 2         5.0
# 3       320.0
# 4       300.0
#         ...
# 1349      1.0
# 1350      1.0
# 1351      1.0
# 1352      1.0
# 1353      1.0
# Name: Number of Bags, Length: 1338, dtype: float64

# %% [markdown]
# # Поиск функциональных зависимостей

# %% [markdown]
# В этом разделе мы анализировали зависимости: кто чем владеет, что более уникально - мельница или фирма? Обо всём этом здесь. Пояснения зависимостей в основном отчёте

# %%
body = data['Certification Body'].unique()
body
# Out:
# array(['METAD Agricultural Development plc',
#        'Specialty Coffee Association',
#        'Specialty Coffee Institute of Asia',
#        'Ethiopia Commodity Exchange', 'Almacafé',
#        'Yunnan Coffee Exchange', 'Blossom Valley International',
#        'AMECAFE', 'NUCOFFEE', 'Uganda Coffee Development Authority',
#        'Instituto Hondureño del Café',
#        'Specialty Coffee Association of Costa Rica',
#        'Kenya Coffee Traders Association',
#        'Africa Fine Coffee Association', 'Asociacion Nacional Del Café',
#        'Centro Agroecológico del Café A.C.', 'Salvadoran Coffee Council',
#        'Specialty Coffee Association of Indonesia',
#        'Brazil Specialty Coffee Association',
#        'Asociación Mexicana De Cafés y Cafeterías De Especialidad A.C.',
#        'Tanzanian Coffee Board',
#        'Central De Organizaciones Productoras De Café y Cacao Del Perú - Central Café & Cacao',
#        'Torch Coffee Lab Yunnan', 'Coffee Quality Institute',
#        'Asociación de Cafés Especiales de Nicaragua'], dtype=object)

# %%
partners = data['In-Country Partner'].unique()
for partner in partners:
    if partner not in body:
        print(partner)
# Out:
# Specialty Coffee Ass
# nan

# %%
nan_index = data[data['In-Country Partner'] != data['Certification Body']].index
data.loc[nan_index, 'In-Country Partner'] = pd.Series('Specialty Coffee Association of Costa Rica', index=nan_index)

# %% [markdown]
# Находим только уникальные ICO Numbers, если значение повторяется - не учитываем строку.

# %%
ICO = {}

forbidden = [118, 162, 199, 266, 458, 612, 1128]
indexes = []

for i in tqdm(range(len(data))):
    if i not in forbidden:
        item = str(data.iloc[i, 12])
        if not any(map(str.isdigit, item)):
            indexes.append(i)
        else:
            if item not in ICO.keys():
                ICO[item] = 1
            else:
                indexes.append(i)
# Out:
# 100%|██████████| 1338/1338 [00:00<00:00, 80176.85it/s]

# %%
data.drop(data.index[indexes], inplace=True)
data.reset_index()
# Out:
#      index quality_score view_certificate_1  view_certificate_2  \
# 0        0         90.58                NaN                 NaN
# 1        7         88.67                NaN                 NaN
# 2        9         88.25                NaN                 NaN
# 3       17         87.33                NaN                 NaN
# 4       19         87.25                NaN                 NaN
# ..     ...           ...                ...                 ...
# 814   1327          83.5                NaN                 NaN
# 815   1333          82.5                NaN                 NaN
# 816   1334          82.5                NaN                 NaN
# 817   1337         81.58                NaN                 NaN
# 818   1352         75.08                NaN                 NaN
#
#      Cupping Protocol and Descriptors  View Green Analysis Details  \
# 0                                 NaN                          NaN
# 1                                 NaN                          NaN
# 2                                 NaN                          NaN
# 3                                 NaN                          NaN
# 4                                 NaN                          NaN
# ..                                ...                          ...
# 814                               NaN                          NaN
# 815                               NaN                          NaN
# 816                               NaN                          NaN
# 817                               NaN                          NaN
# 818                               NaN                          NaN
#
#      Request a Sample  Species                        Owner Country of Origin  \
# 0                 NaN  Arabica                    metad plc          Ethiopia
# 1                 NaN  Arabica  Ethiopia Commodity Exchange          Ethiopia
# 2                 NaN  Arabica       Diamond Enterprise Plc          Ethiopia
# 3                 NaN  Arabica  Ethiopia Commodity Exchange          Ethiopia
# 4                 NaN  Arabica                EssenceCoffee          Ethiopia
# ..                ...      ...                          ...               ...
# 814               NaN  Robusta               Nishant Gurjer             India
# 815               NaN  Robusta               Nishant Gurjer             India
# 816               NaN  Robusta               Nishant Gurjer             India
# 817               NaN  Robusta               Nishant Gurjer             India
# 818               NaN  Robusta                Cafe Politico             India
#
#      ...         Color Category Two Defects NA.3  Expiration  \
# 0    ...         Green                    0  NaN  2016-04-03
# 1    ...           NaN                    0  NaN  2011-09-02
# 2    ...         Green                    4  NaN  2016-03-29
# 3    ...           NaN                    2  NaN  2011-06-16
# 4    ...           NaN                    8  NaN  2016-03-24
# ..   ...           ...                  ...  ...         ...
# 814  ...           NaN                    2  NaN  2018-10-31
# 815  ...  Bluish-Green                    0  NaN  2018-10-25
# 816  ...         Green                    0  NaN  2017-08-17
# 817  ...         Green                    0  NaN  2017-08-23
# 818  ...         Green                    1  NaN  2015-08-25
#
#                      Certification Body  \
# 0    METAD Agricultural Development plc
# 1           Ethiopia Commodity Exchange
# 2    METAD Agricultural Development plc
# 3           Ethiopia Commodity Exchange
# 4          Blossom Valley International
# ..                                  ...
# 814        Specialty Coffee Association
# 815        Specialty Coffee Association
# 816        Specialty Coffee Association
# 817        Specialty Coffee Association
# 818        Specialty Coffee Association
#
#                                  Certification Address  \
# 0    BAWA Center, 3rd Floor (Gerji), Addis Ababa, E...
# 1    Al-Sam Tower 2, 3rd Floor Lideta, Addis Ababa,...
# 2    BAWA Center, 3rd Floor (Gerji), Addis Ababa, E...
# 3    Al-Sam Tower 2, 3rd Floor Lideta, Addis Ababa,...
# 4                     No.72 Mo-Fan St. Taiwan Zip: 403
# ..                                                 ...
# 814        117 W 4th St, Suite 300 Santa Ana, CA 92701
# 815        117 W 4th St, Suite 300 Santa Ana, CA 92701
# 816        117 W 4th St, Suite 300 Santa Ana, CA 92701
# 817        117 W 4th St, Suite 300 Santa Ana, CA 92701
# 818        117 W 4th St, Suite 300 Santa Ana, CA 92701
#
#                                  Certification Contact Unnamed: 51  Notes  \
# 0    Aman Adinew (Emebet Dinku) - +251-116-292534, ...         NaN    NaN
# 1                                   - +251 11 554 7001         NaN    NaN
# 2    Aman Adinew (Emebet Dinku) - +251-116-292534, ...         NaN    NaN
# 3                                   - +251 11 554 7001         NaN    NaN
# 4                         Damon Chen - +886-4-23022323         NaN    NaN
# ..                                                 ...         ...    ...
# 814                        Chris Buck - (562) 624-4100         NaN    NaN
# 815                        Chris Buck - (562) 624-4100         NaN    NaN
# 816                        Chris Buck - (562) 624-4100         NaN    NaN
# 817                        Chris Buck - (562) 624-4100         NaN    NaN
# 818                        Chris Buck - (562) 624-4100         NaN    NaN
#
#     Export Date
# 0    2015-06-13
# 1    2010-10-20
# 2    2015-04-07
# 3    2010-11-07
# 4    2015-09-20
# ..          ...
# 814  2017-11-23
# 815  2018-08-20
# 816  2017-04-24
# 817  2017-06-15
# 818  2015-07-25
#
# [819 rows x 54 columns]

# %%
set1 = set()
forbidden = [100, 125, 172, 311, 419, 725] # уникальные ICO Numbers, но в формате времени

for i in tqdm(range(data.shape[0])):
    if i not in forbidden:
        for j in range(data.shape[1]):
            item = data.iloc[i, j]
            if isinstance(item, str):
                if len(item) > 49:
                    set1.add(j)
                    
print(f'{len(set1)} столбцов с длиной строки больше 49: {set1}')
print('Данная функция нужна для определения оптимальной длины строковых значений')
# Out:
# 100%|██████████| 819/819 [00:00<00:00, 2235.74it/s]
# 12 столбцов с длиной строки больше 49: {7, 9, 11, 13, 15, 48, 49, 16, 19, 47, 51, 22}
# Данная функция нужна для определения оптимальной длины строковых значений

# %%
data.iloc[0, 48]
# Out:
# 'BAWA Center, 3rd Floor (Gerji), Addis Ababa, Ethiopia'

# %%
data['Export Date']
# Out:
# 0       2015-06-13
# 7       2010-10-20
# 9       2015-04-07
# 17      2010-11-07
# 19      2015-09-20
#            ...
# 1327    2017-11-23
# 1333    2018-08-20
# 1334    2017-04-24
# 1337    2017-06-15
# 1352    2015-07-25
# Name: Export Date, Length: 819, dtype: object

# %%
len(data['Producer'].unique())
# Out:
# 413

# %%
len(data['Farm Name'].unique())
# Out:
# 358

# %%
len(data['Mill'].unique())
# Out:
# 324

# %%
len(data['Region'].unique())
# Out:
# 300

# %%
len(data['Company'].unique())
# Out:
# 197

# %% [markdown]
# # Выгрузка файлов

# %% [markdown]
# Разделяем файл по принципу "раньше/позже 2017 года"

# %%
auto_date = data[data['Export Date'] >= datetime.date(2017, 1, 1)]
date = data[data['Export Date'] < datetime.date(2017, 1, 1)]

# %%
part = round(len(date) / 2)
part
# Out:
# 355

# %%
data_for_csv = date[:part]
data_for_excel = date[part:]
data_for_excel_auto = auto_date

# %%
data_for_csv.to_csv("data.csv")
data_for_excel.to_excel("data.xlsx")
data_for_excel_auto.to_excel("data_auto.xlsx")
