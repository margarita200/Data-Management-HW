# %%
import pandas as pd
import numpy as np
import operator
from tqdm import tqdm

# %%
data = pd.read_excel('kofe-2.xlsx')
data.drop('id', axis=1, inplace=True)
data.shape
# Out:
# (1354, 52)

# %%
data.describe()
# Out:
#        Cupping Protocol and Descriptors  View Green Analysis Details  \
# count                               0.0                          0.0
# mean                                NaN                          NaN
# std                                 NaN                          NaN
# min                                 NaN                          NaN
# 25%                                 NaN                          NaN
# 50%                                 NaN                          NaN
# 75%                                 NaN                          NaN
# max                                 NaN                          NaN
#
#        Request a Sample  Number of Bags        Aroma       Flavor  \
# count               0.0     1340.000000  1337.000000  1337.000000
# mean                NaN      154.067910     7.565931     7.519589
# std                 NaN      130.006861     0.380141     0.400798
# min                 NaN        0.000000     0.000000     0.000000
# 25%                 NaN       14.000000     7.420000     7.330000
# 50%                 NaN      172.500000     7.580000     7.580000
# 75%                 NaN      275.000000     7.750000     7.750000
# max                 NaN     1062.000000     8.750000     8.830000
#
#         Aftertaste      Acidity         Body      Balance   Uniformity  \
# count  1337.000000  1337.000000  1337.000000  1337.000000  1337.000000
# mean      7.400120     7.535610     7.520000     7.516126     9.827651
# std       0.405863     0.380411     0.361518     0.417258     0.616560
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       7.250000     7.330000     7.330000     7.330000    10.000000
# 50%       7.420000     7.580000     7.500000     7.500000    10.000000
# 75%       7.580000     7.750000     7.670000     7.750000    10.000000
# max       8.670000     8.750000     8.580000     8.750000    10.000000
#
#          Clean Cup    Sweetness  Cupper Points  NA.2     Moisture  \
# count  1337.000000  1337.000000    1337.000000   0.0  1337.000000
# mean      9.827883     9.847195       7.502573   NaN     0.088265
# std       0.810312     0.684493       0.475396   NaN     0.048373
# min       0.000000     0.000000       0.000000   NaN     0.000000
# 25%      10.000000    10.000000       7.250000   NaN     0.090000
# 50%      10.000000    10.000000       7.500000   NaN     0.110000
# 75%      10.000000    10.000000       7.750000   NaN     0.120000
# max      10.000000    10.000000      10.000000   NaN     0.280000
#
#            Quakers  NA.3  Unnamed: 51
# count  1336.000000   0.0          0.0
# mean      0.173653   NaN          NaN
# std       0.832717   NaN          NaN
# min       0.000000   NaN          NaN
# 25%       0.000000   NaN          NaN
# 50%       0.000000   NaN          NaN
# 75%       0.000000   NaN          NaN
# max      11.000000   NaN          NaN

# %%
def search_nulles(data):
    nulles = data.isnull().sum().sort_values(ascending=False)
    percent = (data.isnull().sum()/data.isnull().count()).sort_values(ascending=False)
    missing_data = pd.concat([nulles, percent], axis=1, keys=['Nulles', 'Percent'])
    return missing_data

search_nulles(data).head(30)
# Out:
#                                   Nulles   Percent
# Cupping Protocol and Descriptors    1354  1.000000
# View Green Analysis Details         1354  1.000000
# NA.3                                1354  1.000000
# Request a Sample                    1354  1.000000
# Unnamed: 51                         1354  1.000000
# NA.2                                1354  1.000000
# view_certificate_2                  1353  0.999261
# view_certificate_1                  1351  0.997784
# Notes                               1349  0.996307
# Lot Number                          1078  0.796160
# Farm Name                            373  0.275480
# Mill                                 329  0.242984
# Producer                             246  0.181684
# Variety                              244  0.180207
# Altitude                             236  0.174298
# Color                                236  0.174298
# Company                              224  0.165436
# Processing Method                    188  0.138848
# ICO Number                           171  0.126292
# Region                                72  0.053176
# Harvest Year                          62  0.045790
# Owner.1                               23  0.016987
# Owner                                 21  0.015510
# Certification Contact                 19  0.014032
# NA                                    19  0.014032
# Quakers                               18  0.013294
# Total Cup Points                      17  0.012555
# Moisture                              17  0.012555
# NA.1                                  17  0.012555
# Category One Defects                  17  0.012555

# %%
print('Так как некоторые столбцы полностью заполнены нулевыми значениями, то их можно удалить')
print('Более того, можно удалить столбцы с более 50% пропусков')
data.drop("Cupping Protocol and Descriptors", axis=1, inplace=True)
data.drop("View Green Analysis Details", axis=1, inplace=True)
data.drop("NA.3", axis=1, inplace=True)
data.drop("Request a Sample", axis=1, inplace=True)
data.drop("Unnamed: 51", axis=1, inplace=True)
data.drop("NA.2", axis=1, inplace=True)
data.drop("view_certificate_2", axis=1, inplace=True)
data.drop("view_certificate_1", axis=1, inplace=True)
data.drop("Notes", axis=1, inplace=True)
data.drop("Lot Number", axis=1, inplace=True)
# Out:
# Так как некоторые столбцы полностью заполнены нулевыми значениями, то их можно удалить
# Более того, можно удалить столбцы с более 50% пропусков

# %%
print('Проверим ещё раз нулевые значения')
search_nulles(data).head(30)
# Out:
# Проверим ещё раз нулевые значения
#                        Nulles   Percent
# Farm Name                 373  0.275480
# Mill                      329  0.242984
# Producer                  246  0.181684
# Variety                   244  0.180207
# Color                     236  0.174298
# Altitude                  236  0.174298
# Company                   224  0.165436
# Processing Method         188  0.138848
# ICO Number                171  0.126292
# Region                     72  0.053176
# Harvest Year               62  0.045790
# Owner.1                    23  0.016987
# Owner                      21  0.015510
# Certification Contact      19  0.014032
# NA                         19  0.014032
# Quakers                    18  0.013294
# Balance                    17  0.012555
# Sweetness                  17  0.012555
# Category Two Defects       17  0.012555
# Category One Defects       17  0.012555
# Moisture                   17  0.012555
# Total Cup Points           17  0.012555
# Cupper Points              17  0.012555
# Certification Body         17  0.012555
# Body                       17  0.012555
# Expiration                 17  0.012555
# Clean Cup                  17  0.012555
# Uniformity                 17  0.012555
# Status                     17  0.012555
# NA.1                       17  0.012555

# %%
print('Заметим, что в самом конце таблицы с нулями есть атрибуты с одинаковым количеством нулей. Посмотрим на эти данные')
print('Есть целые строчки с нулевыми значениям. Так как они не несут нам пользы - удалим их')
search_nulles(data).head(42)
# Out:
# Заметим, что в самом конце таблицы с нулями есть атрибуты с одинаковым количеством нулей. Посмотрим на эти данные
# Есть целые строчки с нулевыми значениям. Так как они не несут нам пользы - удалим их
#                        Nulles   Percent
# Farm Name                 373  0.275480
# Mill                      329  0.242984
# Producer                  246  0.181684
# Variety                   244  0.180207
# Color                     236  0.174298
# Altitude                  236  0.174298
# Company                   224  0.165436
# Processing Method         188  0.138848
# ICO Number                171  0.126292
# Region                     72  0.053176
# Harvest Year               62  0.045790
# Owner.1                    23  0.016987
# Owner                      21  0.015510
# Certification Contact      19  0.014032
# NA                         19  0.014032
# Quakers                    18  0.013294
# Balance                    17  0.012555
# Sweetness                  17  0.012555
# Category Two Defects       17  0.012555
# Category One Defects       17  0.012555
# Moisture                   17  0.012555
# Total Cup Points           17  0.012555
# Cupper Points              17  0.012555
# Certification Body         17  0.012555
# Body                       17  0.012555
# Expiration                 17  0.012555
# Clean Cup                  17  0.012555
# Uniformity                 17  0.012555
# Status                     17  0.012555
# NA.1                       17  0.012555
# Certification Address      17  0.012555
# Aroma                      17  0.012555
# Flavor                     17  0.012555
# Aftertaste                 17  0.012555
# Acidity                    17  0.012555
# Country of Origin          15  0.011078
# Grading Date               15  0.011078
# Species                    14  0.010340
# In-Country Partner         14  0.010340
# Number of Bags             14  0.010340
# Bag Weight                 14  0.010340
# quality_score               9  0.006647

# %%
data[data['Farm Name'].isnull() == False][['Owner', 'Owner.1', 'Farm Name', 'Mill', 'Company', 'Producer']].head(50)
# Out:
#                                  Owner                             Owner.1  \
# 0                            metad plc                           metad plc
# 1                            metad plc                           metad plc
# 2             Grounds for Health Admin            Grounds for Health Admin
# 3                  Yidnekachew Dabessa                 Yidnekachew Dabessa
# 4                            metad plc                           metad plc
# 7          Ethiopia Commodity Exchange         Ethiopia Commodity Exchange
# 8          Ethiopia Commodity Exchange         Ethiopia Commodity Exchange
# 9               Diamond Enterprise Plc              Diamond Enterprise Plc
# 10                       Mohammed Lalo                       Mohammed Lalo
# 11  CQI Q Coffee Sample Representative  CQI Q Coffee Sample Representative
# 12  CQI Q Coffee Sample Representative  CQI Q Coffee Sample Representative
# 13            Grounds for Health Admin            Grounds for Health Admin
# 14         Ethiopia Commodity Exchange         Ethiopia Commodity Exchange
# 15  CQI Q Coffee Sample Representative  CQI Q Coffee Sample Representative
# 16            Grounds for Health Admin            Grounds for Health Admin
# 18              Yunnan Coffee Exchange              Yunnan Coffee Exchange
# 19                       EssenceCoffee                       EssenceCoffee
# 20  CQI Q Coffee Sample Representative  CQI Q Coffee Sample Representative
# 21              The Coffee Source Inc.              The Coffee Source Inc.
# 22               ROBERTO LICONA FRANCO               ROBERTO LICONA FRANCO
# 23  CQI Q Coffee Sample Representative  CQI Q Coffee Sample Representative
# 25                            NUCOFFEE                            NUCOFFEE
# 27               Kabum Trading company               Kabum Trading company
# 28                     Bismarck Castro                     Bismarck Castro
# 29              Lin, Che-Hao Krude 林哲豪              Lin, Che-Hao Krude 林哲豪
# 32                            NUCOFFEE                            NUCOFFEE
# 33                    Francisco A Mena                    Francisco A Mena
# 34                      Hider Abamecha                      Hider Abamecha
# 35                         Daniel Magu                         Daniel Magu
# 37    Kona Pacific Farmers Cooperative    Kona Pacific Farmers Cooperative
# 38         Ethiopia Commodity Exchange         Ethiopia Commodity Exchange
# 39  CQI Q Coffee Sample Representative  CQI Q Coffee Sample Representative
# 40                  ITDP International                  ITDP International
# 41            Jacques Pereira Carneiro            Jacques Pereira Carneiro
# 42            Jacques Pereira Carneiro            Jacques Pereira Carneiro
# 43              Lin, Che-Hao Krude 林哲豪              Lin, Che-Hao Krude 林哲豪
# 44                       Jungle Estate                       Jungle Estate
# 45                            NUCOFFEE                            NUCOFFEE
# 46           Great Lakes Coffee Uganda           Great Lakes Coffee Uganda
# 47                           LUSSO LAB                           LUSSO LAB
# 48                           LUSSO LAB                           LUSSO LAB
# 50         Ethiopia Commodity Exchange         Ethiopia Commodity Exchange
# 51            Grounds for Health Admin            Grounds for Health Admin
# 52           Juan Luis Alvarado Romero           Juan Luis Alvarado Romero
# 53                  Kawacom Uganda LTD                  Kawacom Uganda LTD
# 55                   Gonzalo Hernandez                   Gonzalo Hernandez
# 57           Juan Luis Alvarado Romero           Juan Luis Alvarado Romero
# 58           Juan Luis Alvarado Romero           Juan Luis Alvarado Romero
# 59       SEID DAMTEW COFFEE PLANATAION       SEID DAMTEW COFFEE PLANATAION
# 61           Colbran Coffeelands, Ltd.           Colbran Coffeelands, Ltd.
#
#                                    Farm Name  \
# 0                                  METAD PLC
# 1                                  METAD PLC
# 2   San Marcos Barrancas "San Cristobal Cuch
# 3      Yidnekachew Dabessa Coffee Plantation
# 4                                  METAD PLC
# 7                                      Aolme
# 8                                      Aolme
# 9                          Tulla Coffee Farm
# 10                   Fahem Coffee Plantation
# 11                                   El filo
# 12                                Los Cedros
# 13                             Arianna Farms
# 14                                     Aolme
# 15                                 El Águila
# 16                               Toarco Jaya
# 18                               Echo Coffee
# 19                                Drima Zede
# 20                                  El Rodeo
# 21                                   SEVERAL
# 22                              LA HERRADURA
# 23                                  La curva
# 25                           Fazenda Kaquend
# 27                Chebonet (23) women coffee
# 28                              Los Hicaques
# 29                  Tsoustructive Garden 鄒築園
# 32                           Fazenda Recreio
# 33                    Exclusive Coffees S.A.
# 34         Haider Abamecha Coffee Plantation
# 35                                   Kangunu
# 37                Kona Pacific Farmers Co-Op
# 38  Phone number | 0911-51-08-01, Email | at
# 39                              La Primavera
# 40                                 Co-op #12
# 41                     Pereira Estate Coffee
# 42                     Pereira Estate Coffee
# 43             Sunshine Valley Estate 向陽高山咖啡
# 44                             JUNGLE ESTATE
# 45                           Fazenda Kaquend
# 46                                   Kaasayi
# 47                           Ecobio Colombia
# 48                                  KIANJAVI
# 50           Contact | sidacoop@ethionet.net
# 51                    Hula Daddy Kona Coffee
# 52                     LA ESPERANZA Y ANEXOS
# 53               Sipi organic coffee project
# 55                         La Berlina Estate
# 57                                VALPARAISO
# 58                            FINCA EL LIMON
# 59  seid damtew coffee export and plantation
# 61                    Tairora Cherry – Bonta
#
#                                                  Mill  \
# 0                                           METAD PLC
# 1                                           METAD PLC
# 2                                                 NaN
# 3                                             Wolensu
# 4                                           METAD PLC
# 7                                             C.P.W.E
# 8                                             C.P.W.E
# 9                                   Tulla Coffee Farm
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                            C.P.W.E
# 15                                                NaN
# 16                                                NaN
# 18                                   Echo Coffee Mill
# 19                                         Drima Zede
# 20                                                NaN
# 21                           CAFE DE ALTURA SAN RAMON
# 22                                       LA HERRADURA
# 23                                                NaN
# 25                                                NaN
# 27                              Kabum trading company
# 28                                CIGRAH S.A. DE C.V.
# 29                           Tsoustructive Garden 鄒築園
# 32                                                NaN
# 33                             Exclusive Coffees S.A,
# 34      Faysal Abamecha Processing Plant at yebu Town
# 35                         central kenya coffee mills
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                           Cocarive
# 42                                           Cocarive
# 43                      Sunshine Valley Estate 向陽高山咖啡
# 44                                   NKG COFFEE MILLS
# 45                                                NaN
# 46                                        Great Lakes
# 47                                                NaN
# 48                                                NaN
# 50           Coffee Processing and Warehouse Enterpri
# 51                                                NaN
# 52                                   BENEFICIO IXCHEL
# 53                                    Kawacom (U) Ltd
# 55                           Beneficio Casa Ruiz S.A.
# 57                               BENEFICIO VALPARAISO
# 58  BENEFICIO SERBEN KM 21.5 CARRETERA A VILLA CAN...
# 59           seid damtew coffee export and plantation
# 61                                            Baroida
#
#                                   Company  \
# 0       METAD Agricultural Developmet plc
# 1       METAD Agricultural Developmet plc
# 2                                     NaN
# 3   Yidnekachew Debessa Coffee Plantation
# 4       METAD Agricultural Developmet plc
# 7                                     NaN
# 8                                     NaN
# 9                  DIAMOND ENTERPRISE PLC
# 10                Fahem Coffee Plantation
# 11               Coffee Quality Institute
# 12               Coffee Quality Institute
# 13                                    NaN
# 14                                    NaN
# 15               Coffee Quality Institute
# 16                                    NaN
# 18                 Yunnan Coffee Exchange
# 19                         Essence Coffee
# 20               Coffee Quality Institute
# 21                 The Coffee Source Inc.
# 22                                    NaN
# 23               Coffee Quality Institute
# 25                               NUCOFFEE
# 27                  Kabum Trading company
# 28                      CIGRAH S.A DE C.V
# 29               Taiwan Coffee Laboratory
# 32                               NUCOFFEE
# 33                 Exclusive Coffees S.A.
# 34          Haider Abamecha Coffee Export
# 35                           C dorman Ltd
# 37                                    NaN
# 38                                    NaN
# 39               Coffee Quality Institute
# 40                             Lanna Cafe
# 41                                    NaN
# 42                                    NaN
# 43               Taiwan Coffee Laboratory
# 44                       Keremara Limited
# 45                               NUCOFFEE
# 46                                   UCDA
# 47                       LUSSO COFFEE LAB
# 48                       LUSSO COFFEE LAB
# 50                                    NaN
# 51                                    NaN
# 52                   UNEX GUATEMALA, S.A.
# 53                     Kawacom uganda LTD
# 55                      CE Specialty S.A.
# 57                               SERTRASA
# 58                           UNICAFE, S.A
# 59           Seid Damtew Coffee Planation
# 61                                    CQI
#
#                                      Producer
# 0                                   METAD PLC
# 1                                   METAD PLC
# 2                                         NaN
# 3       Yidnekachew Dabessa Coffee Plantation
# 4                                   METAD PLC
# 7   Bazen Agricultural & Industrial Dev't Plc
# 8   Bazen Agricultural & Industrial Dev't Plc
# 9                      Diamond Enterprise Plc
# 10                    Fahem Coffee Plantation
# 11               Alfredo De Jesús López Pérez
# 12                      Jorge Walter Restrepo
# 13               Robert, Sharon, Arianna Wood
# 14  Bazen Agricultural & Industrial Dev't Plc
# 15                        María Leticia Diosa
# 16                           P.T. Toarco Jaya
# 18                                Echo Coffee
# 19                                    LevelUp
# 20                       Nicolás Rueda Urrego
# 21                                    SEVERAL
# 22                      ROBERTO LICONA FRANCO
# 23                       Silvia Elena Higuita
# 25                            Ralph Junqueira
# 27                      Kabum trading company
# 28                            Reinerio Zepeda
# 29                         FANG,ZHENG-LUN 方政倫
# 32            Homero Texeira de Macedo Junior
# 33                     Exclusive Coffees S.A.
# 34                    Haider Abamecha Abadiko
# 35                                    Kangunu
# 37                 Kona Pacific Farmers Co-Op
# 38          Contact name | ATO Teshome Belamo
# 39                     Hugo Sepúlveda Montoya
# 40                                       ITDP
# 41                Maria Rogeria Costa Pereira
# 42                Maria Rogeria Costa Pereira
# 43                          LIN YEN CHIEN 林言謙
# 44                              JUNGLE ESTATE
# 45                            Ralph Junqueira
# 46                        Kaasay Farmer Group
# 47                                        NaN
# 48                                        NaN
# 50          Sidama Coffee Farmers Coop. Union
# 51                     Hula Daddy Kona Coffee
# 52                  MARGARITA AVILA DE NUYENS
# 53                             Kawacom (U)Ltd
# 55                                Plinio Ruiz
# 57                                   SERTRASA
# 58          WILLIAM ESTUARDO MARTINEZ PACHECO
# 59   seid damtew coffee export and plantation
# 61                  Colbran CoffeeLands, Ltd.

# %%
data[data['Owner'] != data['Owner.1']][['Owner', 'Owner.1']]
# Out:
#                          Owner    Owner.1
# 219                 CECA, S.A.  CECA,S.A.
# 364                        NaN        NaN
# 459                        NaN        NaN
# 602                        NaN        NaN
# 848                        NaN        NaN
# 882                        NaN        NaN
# 918                        NaN        NaN
# 921                        NaN        NaN
# 922                        NaN        NaN
# 964              Klem Organics        NaN
# 965                        NaN        NaN
# 966                        NaN        NaN
# 967                        NaN        NaN
# 981                        NaN        NaN
# 1050                       NaN        NaN
# 1089  CQI Taiwan ICP CQI台灣合作夥伴        NaN
# 1090                       NaN        NaN
# 1091                       NaN        NaN
# 1092                       NaN        NaN
# 1093                       NaN        NaN
# 1094                       NaN        NaN
# 1095                       NaN        NaN
# 1242                       NaN        NaN
# 1243                       NaN        NaN

# %%
data.drop("Owner.1", axis=1, inplace=True)
print('Удаляем Owner.1 тк этот столбец фактически дублирует Owner')
# Out:
# Удаляем Owner.1 тк этот столбец фактически дублирует Owner

# %%
nulles = {}

def isNaN(num):
    return num != num

def NaN_in_row(data):
    i = 0
    while i < len(data):
        line = data.iloc[i]
        for item in line:
            if isNaN(item):
                if i in nulles.keys():
                    nulles[i] += 1
                else:
                    nulles[i] = 1
        i += 1
    return dict(sorted(nulles.items(), key=operator.itemgetter(1), reverse=True))

print('Посмотрим, сколько есть записей с нулевыми ячейками')
nulles = NaN_in_row(data)
list(nulles.items())[:20]
# Out:
# Посмотрим, сколько есть записей с нулевыми ячейками
# [(918, 41),
#  (922, 41),
#  (967, 41),
#  (1091, 41),
#  (1093, 41),
#  (1094, 41),
#  (1095, 41),
#  (1242, 41),
#  (1243, 41),
#  (921, 40),
#  (965, 40),
#  (966, 40),
#  (1090, 40),
#  (1092, 40),
#  (1089, 28),
#  (964, 26),
#  (920, 25),
#  (1209, 11),
#  (334, 10),
#  (373, 10)]

# %%
d = dict((k, v) for k, v in nulles.items() if v >= 40)
drop = list(d)

data.drop(data.index[drop], inplace=True)

data.reset_index(drop=True)
print('Удалим строки, в которых больше 39 нулевых значений \nтк вряд ли они несут пользу для нашего анализа, ведь всего 42 столбца')
# Out:
# Удалим строки, в которых больше 39 нулевых значений
# тк вряд ли они несут пользу для нашего анализа, ведь всего 42 столбца

# %%
data[data['NA'] != data['NA.1']][['NA', 'NA.1']]
data.drop("NA", axis=1, inplace=True)
print('Удаляем NA тк этот столбец фактически дублирует NA.1')
# Out:
# Удаляем NA тк этот столбец фактически дублирует NA.1

# %%
data[data['Owner'].isnull()][['Owner', 'Farm Name', 'Mill', 'Company', 'Producer']].head(21)
# Out:
#      Owner                   Farm Name         Mill        Company  \
# 364    NaN                Los Hicaques   CIGRAH SPS         CIGRAH
# 459    NaN                Los Hicaques   CIGRAH SPS         CIGRAH
# 602    NaN  Supply Chain ECOM CCA S.A.  South Huila  ECOM CCA S.A.
# 848    NaN  Gran Manzana y el Aguacate   CIGRAH SPS         CIGRAH
# 882    NaN  Gran Manzana y el Aguacate   CIGRAH SPS         CIGRAH
# 981    NaN                Los Hicaques       CIGRAH         CIGRAH
# 1050   NaN                Los Hicaques       CIGRAH         CIGRAH
#
#                         Producer
# 364              Reynerio Zepeda
# 459              Reynerio Zepeda
# 602   Supply Chain ECOM CCA S.A.
# 848      Tomás Sosa, Juan Damaso
# 882      Tomás Sosa, Juan Damaso
# 981              Reinerio Zepeda
# 1050             Reinerio Zepeda

# %%
data[data['Company'] == 'CIGRAH'][['Owner', 'Farm Name', 'Mill', 'Company', 'Producer', 'Region', 'Altitude', 'ICO Number', 'In-Country Partner']].head(21)
# Out:
#            Owner                   Farm Name               Mill Company  \
# 364          NaN                Los Hicaques         CIGRAH SPS  CIGRAH
# 459          NaN                Los Hicaques         CIGRAH SPS  CIGRAH
# 655   Elsy Reyes               Las Cuchillas  CIGRAH S.A DE C.V  CIGRAH
# 848          NaN  Gran Manzana y el Aguacate         CIGRAH SPS  CIGRAH
# 882          NaN  Gran Manzana y el Aguacate         CIGRAH SPS  CIGRAH
# 912   Elsy Reyes               LAS CUCHILLAS             CIGRAH  CIGRAH
# 981          NaN                Los Hicaques             CIGRAH  CIGRAH
# 1050         NaN                Los Hicaques             CIGRAH  CIGRAH
#
#                      Producer          Region   Altitude  ICO Number  \
# 364           Reynerio Zepeda       Comayagua       1350  13-111-240
# 459           Reynerio Zepeda       Comayagua       1350  13-111-193
# 655           Nahun Maldonado       Comayagua       1400  13-111-097
# 848   Tomás Sosa, Juan Damaso       Comayagua       1350  13-111-311
# 882   Tomás Sosa, Juan Damaso       Comayagua       1400  13-111-192
# 912           NAHUN MALDONADO       COMAYAGUA       1400  13-111-083
# 981           Reinerio Zepeda  Central Region  1450 mals  13-111-037
# 1050          Reinerio Zepeda  Central Region  1450 mals  13-111-035
#
#                 In-Country Partner
# 364   Instituto Hondureño del Café
# 459   Instituto Hondureño del Café
# 655   Instituto Hondureño del Café
# 848   Instituto Hondureño del Café
# 882   Instituto Hondureño del Café
# 912   Instituto Hondureño del Café
# 981   Instituto Hondureño del Café
# 1050  Instituto Hondureño del Café

# %%
owner = data[data['Company'] == 'CIGRAH']['Owner'].unique()[1]
nan_index = data[data['Owner'].isnull()].index
data.loc[nan_index, 'Owner'] = pd.Series(owner, index=nan_index)
print('Так как мы хотим использовать Owner как первичный составной ключ, \nто нельзя допустить в нём нулевые значения. Заполняем их уникальным значением владельца в этой компании')
# Out:
# Так как мы хотим использовать Owner как первичный составной ключ,
# то нельзя допустить в нём нулевые значения. Заполняем их уникальным значением владельца в этой компании

# %%
data[data['Quakers'].isnull() == False]['Quakers'].unique()
# Out:
# array([ 0.,  1.,  4.,  2.,  5.,  6.,  3., 11.,  7.,  9.,  8.])

# %%
def split_weight(data):
    for i in tqdm(range(len(data))):
        item = data.iloc[i, 12]
        if isinstance(item, int):
            weigth = item
        else:
            words = item.split(' ')
            weigth = int(words[0])
            if len(words) > 1:
                metric = words[1]
                if metric.lower().strip() == 'lbs':
                    weigth = weigth * 0.453592
        data.iloc[i, 12] = round(weigth, 3)
    return data

# %%
data = split_weight(data)
data['Bag Weight']
# data.iloc[0, 12]
# Out:
# 100%|██████████| 1340/1340 [00:00<00:00, 1610.96it/s]
# 0          60
# 1          60
# 2           1
# 3          60
# 4          60
#         ...
# 1349        2
# 1350        2
# 1351        1
# 1352    2.268
# 1353    2.268
# Name: Bag Weight, Length: 1340, dtype: object

# %%
def split_defects(data, number='one'):
    for i in tqdm(range(len(data))):
        if number == 'one':
            k = 32
        elif number == 'two':
            k = 35
        item = data.iloc[i, k]
        if isNaN(item) is False:
            words = item.split(' ')
            defects = int(words[0])
        data.iloc[i, k] = defects
            
    return data

# %%
data = split_defects(data)
data = split_defects(data, 'two')
# Out:
# 100%|██████████| 1340/1340 [00:00<00:00, 2135.79it/s]
# 100%|██████████| 1340/1340 [00:00<00:00, 2110.58it/s]

# %%
data.head(30)
# Out:
#    quality_score  Species                               Owner  \
# 0          90.58  Arabica                           metad plc
# 1          89.92  Arabica                           metad plc
# 2          89.75  Arabica            Grounds for Health Admin
# 3             89  Arabica                 Yidnekachew Dabessa
# 4          88.83  Arabica                           metad plc
# 5          88.83  Arabica                           Ji-Ae Ahn
# 6          88.75  Arabica                       Hugo Valdivia
# 7          88.67  Arabica         Ethiopia Commodity Exchange
# 8          88.42  Arabica         Ethiopia Commodity Exchange
# 9          88.25  Arabica              Diamond Enterprise Plc
# 10         88.08  Arabica                       Mohammed Lalo
# 11         87.92  Arabica  CQI Q Coffee Sample Representative
# 12         87.92  Arabica  CQI Q Coffee Sample Representative
# 13         87.92  Arabica            Grounds for Health Admin
# 14         87.83  Arabica         Ethiopia Commodity Exchange
# 15         87.58  Arabica  CQI Q Coffee Sample Representative
# 16         87.42  Arabica            Grounds for Health Admin
# 17         87.33  Arabica         Ethiopia Commodity Exchange
# 18         87.25  Arabica              Yunnan Coffee Exchange
# 19         87.25  Arabica                       EssenceCoffee
# 20         87.25  Arabica  CQI Q Coffee Sample Representative
# 21         87.17  Arabica              The Coffee Source Inc.
# 22         87.17  Arabica               ROBERTO LICONA FRANCO
# 23         87.08  Arabica  CQI Q Coffee Sample Representative
# 24         87.08  Arabica                           Ji-Ae Ahn
# 25         86.92  Arabica                            NUCOFFEE
# 26         86.92  Arabica         Ethiopia Commodity Exchange
# 27         86.83  Arabica               Kabum Trading company
# 28         86.67  Arabica                     Bismarck Castro
# 29         86.58  Arabica              Lin, Che-Hao Krude 林哲豪
#
#          Country of Origin                                 Farm Name  \
# 0                 Ethiopia                                 METAD PLC
# 1                 Ethiopia                                 METAD PLC
# 2                Guatemala  San Marcos Barrancas "San Cristobal Cuch
# 3                 Ethiopia     Yidnekachew Dabessa Coffee Plantation
# 4                 Ethiopia                                 METAD PLC
# 5                   Brazil                                       NaN
# 6                     Peru                                       NaN
# 7                 Ethiopia                                     Aolme
# 8                 Ethiopia                                     Aolme
# 9                 Ethiopia                         Tulla Coffee Farm
# 10                Ethiopia                   Fahem Coffee Plantation
# 11           United States                                   El filo
# 12           United States                                Los Cedros
# 13  United States (Hawaii)                             Arianna Farms
# 14                Ethiopia                                     Aolme
# 15           United States                                 El Águila
# 16               Indonesia                               Toarco Jaya
# 17                Ethiopia                                       NaN
# 18                   China                               Echo Coffee
# 19                Ethiopia                                Drima Zede
# 20           United States                                  El Rodeo
# 21              Costa Rica                                   SEVERAL
# 22                  Mexico                              LA HERRADURA
# 23           United States                                  La curva
# 24                Ethiopia                                       NaN
# 25                  Brazil                           Fazenda Kaquend
# 26                Ethiopia                                       NaN
# 27                  Uganda                Chebonet (23) women coffee
# 28                Honduras                              Los Hicaques
# 29                  Taiwan                  Tsoustructive Garden 鄒築園
#
#                         Mill       ICO Number  \
# 0                  METAD PLC        2014/2015
# 1                  METAD PLC        2014/2015
# 2                        NaN              NaN
# 3                    Wolensu              NaN
# 4                  METAD PLC        2014/2015
# 5                        NaN              NaN
# 6                        HVC              NaN
# 7                    C.P.W.E         010/0338
# 8                    C.P.W.E         010/0338
# 9          Tulla Coffee Farm          2014/15
# 10                       NaN              NaN
# 11                       NaN          unknown
# 12                       NaN          unknown
# 13                       NaN              NaN
# 14                   C.P.W.E         010/0338
# 15                       NaN          unknown
# 16                       NaN              NaN
# 17                       NaN         010/0056
# 18          Echo Coffee Mill              NaN
# 19                Drima Zede        100181006
# 20                       NaN          unknown
# 21  CAFE DE ALTURA SAN RAMON       5-562-0015
# 22              LA HERRADURA                0
# 23                       NaN          unknown
# 24                       NaN              NaN
# 25                       NaN    002/1251/0073
# 26                       NaN  010/0056/Sidamo
# 27     Kabum trading company                0
# 28       CIGRAH S.A. DE C.V.       13-111-053
# 29  Tsoustructive Garden 鄒築園           Taiwan
#
#                                   Company                       Altitude  \
# 0       METAD Agricultural Developmet plc                      1950-2200
# 1       METAD Agricultural Developmet plc                      1950-2200
# 2                                     NaN                  1600 - 1800 m
# 3   Yidnekachew Debessa Coffee Plantation                      1800-2200
# 4       METAD Agricultural Developmet plc                      1950-2200
# 5                                     NaN                            NaN
# 6   Richmond Investment-coffee department                            NaN
# 7                                     NaN                      1570-1700
# 8                                     NaN                      1570-1700
# 9                  DIAMOND ENTERPRISE PLC                      1795-1850
# 10                Fahem Coffee Plantation                      1855-1955
# 11               Coffee Quality Institute  Meters above sea level: 1.872
# 12               Coffee Quality Institute  Meters above sea level: 1.943
# 13                                    NaN                        2000 ft
# 14                                    NaN                      1570-1700
# 15               Coffee Quality Institute  Meters above sea level: 2.080
# 16                                    NaN                     1200-1800m
# 17                                    NaN                            NaN
# 18                 Yunnan Coffee Exchange                           1450
# 19                         Essence Coffee                     1700-2000m
# 20               Coffee Quality Institute  Meters above sea level: 2.019
# 21                 The Coffee Source Inc.                      1300 MSNM
# 22                                    NaN                           1320
# 23               Coffee Quality Institute  Meters above sea level: 2.112
# 24                                    NaN                            NaN
# 25                               NUCOFFEE                          1250m
# 26                                    NaN                            NaN
# 27                  Kabum Trading company                           1950
# 28                      CIGRAH S.A DE C.V                           1400
# 29               Taiwan Coffee Laboratory                           1200
#
#                                                Region  ... Total Cup Points  \
# 0                                   GUJI-HAMBELA/GOYO  ...    Sample  90.58
# 1                                  GUJI-HAMBELA/ALAKA  ...    Sample  89.92
# 2                                                 NaN  ...    Sample  89.75
# 3                                              Oromia  ...    Sample  89.00
# 4                            GUJI-HAMBELA/BISHAN FUGU  ...    Sample  88.83
# 5                                                 NaN  ...    Sample  88.83
# 6                                                 NaN  ...    Sample  88.75
# 7                                              Oromia  ...    Sample  88.67
# 8                                             Oromiya  ...    Sample  88.42
# 9                         SNNP/Kaffa Zone,GimboWereda  ...    Sample  88.25
# 10                                             Oromia  ...    Sample  88.08
# 11                                  Antioquía-Giraldo  ...    Sample  87.92
# 12                                  Antioquía-Betulia  ...    Sample  87.92
# 13                                               Kona  ...    Sample  87.92
# 14                                            Oromiya  ...    Sample  87.83
# 15                                  Antioquía-Caicedo  ...    Sample  87.58
# 16                                           Sulawesi  ...    Sample  87.42
# 17                                        Yirgacheffe  ...    Sample  87.33
# 18  Yunnan Province XiShuangBanNa City Menghai County  ...    Sample  87.25
# 19                                              Gedio  ...    Sample  87.25
# 20                                  Antioquía-Betulia  ...    Sample  87.25
# 21                                          SAN RAMON  ...    Sample  87.17
# 22                                             XALAPA  ...    Sample  87.17
# 23                                  Antioquía-Giraldo  ...    Sample  87.08
# 24                                             Sidamo  ...    Sample  87.08
# 25                                     South of Minas  ...    Sample  86.92
# 26                                             Sidamo  ...    Sample  86.92
# 27                                  Kapchorwa Eastern  ...    Sample  86.83
# 28                                          Comayagua  ...    Sample  86.67
# 29              Leye, Alishan Township, Chiayi County  ...    Sample  86.58
#
#     Moisture Category One Defects Quakers         Color Category Two Defects  \
# 0       0.12                    0     0.0         Green                    0
# 1       0.12                    0     0.0         Green                    1
# 2       0.00                    0     0.0           NaN                    0
# 3       0.11                    0     0.0         Green                    2
# 4       0.12                    0     0.0         Green                    2
# 5       0.11                    0     0.0  Bluish-Green                    1
# 6       0.11                    0     0.0  Bluish-Green                    0
# 7       0.03                    0     0.0           NaN                    0
# 8       0.03                    0     0.0           NaN                    0
# 9       0.10                    0     0.0         Green                    4
# 10      0.10                    0     0.0           NaN                    1
# 11      0.00                    0     0.0           NaN                    0
# 12      0.00                    0     0.0           NaN                    0
# 13      0.00                    0     0.0           NaN                    2
# 14      0.05                    0     0.0           NaN                    2
# 15      0.00                    0     0.0           NaN                    0
# 16      0.03                    0     0.0           NaN                    0
# 17      0.05                    0     0.0           NaN                    2
# 18      0.10                    0     0.0         Green                    0
# 19      0.00                    0     0.0           NaN                    8
# 20      0.00                    0     0.0          None                    0
# 21      0.11                    0     0.0         Green                    2
# 22      0.13                    0     0.0         Green                    0
# 23      0.00                    0     0.0           NaN                    0
# 24      0.11                    0     0.0  Bluish-Green                    1
# 25      0.12                    0     0.0         Green                    2
# 26      0.05                    0     0.0           NaN                    2
# 27      0.12                    0     0.0         Green                    1
# 28      0.10                    0     0.0         Green                    3
# 29      0.00                    0     0.0         Green                    0
#
#               Expiration                   Certification Body  \
# 0        April 3rd, 2016   METAD Agricultural Development plc
# 1        April 3rd, 2016   METAD Agricultural Development plc
# 2         May 31st, 2011         Specialty Coffee Association
# 3       March 25th, 2016   METAD Agricultural Development plc
# 4        April 3rd, 2016   METAD Agricultural Development plc
# 5    September 3rd, 2014   Specialty Coffee Institute of Asia
# 6   September 17th, 2013   Specialty Coffee Institute of Asia
# 7    September 2nd, 2011          Ethiopia Commodity Exchange
# 8    September 2nd, 2011          Ethiopia Commodity Exchange
# 9       March 29th, 2016   METAD Agricultural Development plc
# 10      March 26th, 2016   METAD Agricultural Development plc
# 11      March 12th, 2016                             Almacafé
# 12      March 12th, 2016                             Almacafé
# 13        May 31st, 2011         Specialty Coffee Association
# 14     August 31st, 2011          Ethiopia Commodity Exchange
# 15      March 12th, 2016                             Almacafé
# 16        May 31st, 2011         Specialty Coffee Association
# 17       June 16th, 2011          Ethiopia Commodity Exchange
# 18       April 7th, 2017               Yunnan Coffee Exchange
# 19      March 24th, 2016         Blossom Valley International
# 20      March 12th, 2016                             Almacafé
# 21       April 2nd, 2015         Specialty Coffee Association
# 22       July 26th, 2013                              AMECAFE
# 23      March 12th, 2016                             Almacafé
# 24   September 3rd, 2014   Specialty Coffee Institute of Asia
# 25    December 2nd, 2012                             NUCOFFEE
# 26       June 16th, 2011          Ethiopia Commodity Exchange
# 27       June 26th, 2015  Uganda Coffee Development Authority
# 28        May 18th, 2018         Instituto Hondureño del Café
# 29        May 18th, 2017         Specialty Coffee Association
#
#                                 Certification Address  \
# 0   BAWA Center, 3rd Floor (Gerji), Addis Ababa, E...
# 1   BAWA Center, 3rd Floor (Gerji), Addis Ababa, E...
# 2         117 W 4th St, Suite 300 Santa Ana, CA 92701
# 3   BAWA Center, 3rd Floor (Gerji), Addis Ababa, E...
# 4   BAWA Center, 3rd Floor (Gerji), Addis Ababa, E...
# 5   3F, 259-1 Ulgiro-3-ga, Joong-gu, Seoul, South ...
# 6   3F, 259-1 Ulgiro-3-ga, Joong-gu, Seoul, South ...
# 7   Al-Sam Tower 2, 3rd Floor Lideta, Addis Ababa,...
# 8   Al-Sam Tower 2, 3rd Floor Lideta, Addis Ababa,...
# 9   BAWA Center, 3rd Floor (Gerji), Addis Ababa, E...
# 10  BAWA Center, 3rd Floor (Gerji), Addis Ababa, E...
# 11  Calle 73 No. 8-13 Piso 2 Torre B Bogota, Colombia
# 12  Calle 73 No. 8-13 Piso 2 Torre B Bogota, Colombia
# 13        117 W 4th St, Suite 300 Santa Ana, CA 92701
# 14  Al-Sam Tower 2, 3rd Floor Lideta, Addis Ababa,...
# 15  Calle 73 No. 8-13 Piso 2 Torre B Bogota, Colombia
# 16        117 W 4th St, Suite 300 Santa Ana, CA 92701
# 17  Al-Sam Tower 2, 3rd Floor Lideta, Addis Ababa,...
# 18  Warehouse of YCE, Chuangye Road, Munaihe Indus...
# 19                   No.72 Mo-Fan St. Taiwan Zip: 403
# 20  Calle 73 No. 8-13 Piso 2 Torre B Bogota, Colombia
# 21        117 W 4th St, Suite 300 Santa Ana, CA 92701
# 22  Tenayuca 107 Col. Vertiz Narvarte México D.F. ...
# 23  Calle 73 No. 8-13 Piso 2 Torre B Bogota, Colombia
# 24  3F, 259-1 Ulgiro-3-ga, Joong-gu, Seoul, South ...
# 25               Av. Nações Unidas, 18.001 - 5° floor
# 26  Al-Sam Tower 2, 3rd Floor Lideta, Addis Ababa,...
# 27  Coffee House, Plot 35, Jinja Road, P.O. Box 72...
# 28  Laboratorio de Control de Calidad de Café ( CN...
# 29        117 W 4th St, Suite 300 Santa Ana, CA 92701
#
#                                 Certification Contact
# 0   Aman Adinew (Emebet Dinku) - +251-116-292534, ...
# 1   Aman Adinew (Emebet Dinku) - +251-116-292534, ...
# 2                         Chris Buck - (562) 624-4100
# 3   Aman Adinew (Emebet Dinku) - +251-116-292534, ...
# 4   Aman Adinew (Emebet Dinku) - +251-116-292534, ...
# 5   Sung-Yong Steven Kil - 82-10-7912-1456-English...
# 6   Sung-Yong Steven Kil - 82-10-7912-1456-English...
# 7                                  - +251 11 554 7001
# 8                                  - +251 11 554 7001
# 9   Aman Adinew (Emebet Dinku) - +251-116-292534, ...
# 10  Aman Adinew (Emebet Dinku) - +251-116-292534, ...
# 11                          Rodrigo Alarcon - 3136600
# 12                          Rodrigo Alarcon - 3136600
# 13                        Chris Buck - (562) 624-4100
# 14                                 - +251 11 554 7001
# 15                          Rodrigo Alarcon - 3136600
# 16                        Chris Buck - (562) 624-4100
# 17                                 - +251 11 554 7001
# 18                          Zooey Li - +8608792891121
# 19                       Damon Chen - +886-4-23022323
# 20                          Rodrigo Alarcon - 3136600
# 21                        Chris Buck - (562) 624-4100
# 22         Sylvia Gutiérrez - 52-55-56884569 ext 6792
# 23                          Rodrigo Alarcon - 3136600
# 24  Sung-Yong Steven Kil - 82-10-7912-1456-English...
# 25                                                  -
# 26                                 - +251 11 554 7001
# 27           Clare Rwakatogoro - 256-41-256940/233073
# 28                      Ramon Reyes - + 504 9693-9042
# 29                        Chris Buck - (562) 624-4100
#
# [30 rows x 40 columns]

# %%
# part = int(len(data) / 4)
# data_for_csv = data[:part]
# data_for_csv_auto = data[part:2 * part]
# data_for_excel = data[2 * part: 3 * part]
# data_for_excel_auto = data[3 * part:]

# data_for_csv.to_csv("output.csv")
# data_for_csv_auto.to_csv("output_auto.csv")
# data_for_excel.to_excel("output.xlsx") 
# data_for_excel_auto.to_excel("output_auto.xlsx")
